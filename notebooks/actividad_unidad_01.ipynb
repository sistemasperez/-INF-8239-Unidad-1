# %% [markdown]
# # Actividad Unidad 1
#
# ## 1. Experimento Base
# Describe y ejecuta aquí el procedimiento inicial del experimento.
#
# ---
#
# ## 2. Adaptación del Laboratorio
# **¿Qué cambió?**
# **¿Por qué se cambió (hipótesis)?**

# %%
# Tu código adaptado aquí

# %% [markdown]
# ---
# ## 3. Comparación y Conclusiones
# Compara las métricas (base vs. adaptado) y redacta tus conclusiones.
